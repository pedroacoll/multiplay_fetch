# %%
import matplotlib.pyplot as plt

import numpy as np

import os

import pandas as pd

# %%
file='./OxCGRT_latest.csv'

# %%
data = pd.read_csv(file)

# %%
data.columns
# Out:
# Index(['CountryName', 'CountryCode', 'Date', 'C1_School closing', 'C1_Flag',
#        'C2_Workplace closing', 'C2_Flag', 'C3_Cancel public events', 'C3_Flag',
#        'C4_Restrictions on gatherings', 'C4_Flag', 'C5_Close public transport',
#        'C5_Flag', 'C6_Stay at home requirements', 'C6_Flag',
#        'C7_Restrictions on internal movement', 'C7_Flag',
#        'C8_International travel controls', 'E1_Income support', 'E1_Flag',
#        'E2_Debt/contract relief', 'E3_Fiscal measures',
#        'E4_International support', 'H1_Public information campaigns',
#        'H1_Flag', 'H2_Testing policy', 'H3_Contact tracing',
#        'H4_Emergency investment in healthcare', 'H5_Investment in vaccines',
#        'M1_Wildcard', 'ConfirmedCases', 'ConfirmedDeaths', 'StringencyIndex',
#        'StringencyIndexForDisplay', 'StringencyLegacyIndex',
#        'StringencyLegacyIndexForDisplay', 'GovernmentResponseIndex',
# ...

# %%
#confirmed_deaths= list(data.columns[0:3])+list(data.columns[-12:-10])
#data_death=data[confirmed_deaths]
#data_death

# %%
lista_codigo_pais=[data.loc[0,"CountryCode"]]
nombre_pais=[data.loc[0,"CountryName"]]
fechas=[data.loc[0,"Date"]]
lista_muertos=[]
lista_enfermos=[]
lista_stringency=[]
num_paises=1
e=0
lista_peq_muertos=[]
lista_peq_enfermos=[]
lista_peq_stringency=[]
indice_nulo=1
for index, rows in data.iterrows():
    
    if rows.CountryCode != lista_codigo_pais[-1]:
        lista_muertos.append(lista_peq_muertos)
        lista_enfermos.append(lista_peq_enfermos)
        lista_stringency.append(lista_peq_stringency)
        #print('nuevo pais ' + str(num_paises))
        
        indice_nulo=1
        e=1
        lista_codigo_pais.append(rows.CountryCode)
        num_paises+=1
        lista_datos_pais.append(lista_peq)

        lista_peq_muertos=[rows.ConfirmedDeaths]
        lista_peq_enfermos=[rows.ConfirmedCases]
        lista_peq_stringency=[rows.StringencyIndexForDisplay]
        nombre_pais.append(rows.CountryName)
    else: 
        print('nuevo dato del pais ' + str(num_paises))
        lista_peq_muertos.append([rows.ConfirmedDeaths])
        lista_peq_enfermos.append([rows.ConfirmedCases])
        lista_peq_stringency.append([rows.StringencyIndexForDisplay])
    if e==0:
        fechas.append(rows.Date)
# Out:
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# nuevo dato del pais 1
# ...

# %%
len(lista_muertos)
# Out:
# 26069

# %%
from datetime import datetime
fechas_transformadas= [datetime.strptime(str(x), '%Y%m%d') for x in fechas]

# %%
df_deaths=pd.DataFrame(lista_muertos, index=lista_codigo_pais,columns=fechas_transformadas)
#df_sick=pd.DataFrame(lista_enfermos, index=lista_codigo_pais,columns=fechas_transformadas)
#df_string=pd.DataFrame(lista_stringency, index=lista_codigo_pais,columns=fechas_transformadas)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     499         result = _convert_object_array(
# --> 500             content, columns, dtype=dtype, coerce_float=coerce_float
#     501         )
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals/construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     582                 "{col:d} columns passed, passed data had "
# --> 583                 "{con} columns".format(col=len(columns), con=len(content))
#     584             )
#
# AssertionError: 154 columns passed, passed data had 25899 columns
#
# The above exception was the direct cause of the following exception:
#
# ...
