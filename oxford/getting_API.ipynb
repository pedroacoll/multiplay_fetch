# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
url='https://covidtrackerapi.bsg.ox.ac.uk/api/v2/stringency/date-range/2020-03-01/2020-03-31'
JSONContent = requests.get(url).json()
content = json.dumps(JSONContent, indent = 4, sort_keys=True)
print(content)
# Out:
# {
#     "countries": [
#         "ABW",
#         "AFG",
#         "AGO",
#         "ALB",
#         "AND",
#         "ARE",
#         "ARG",
#         "AUS",
#         "AUT",
#         "AZE",
#         "BDI",
#         "BEL",
#         "BEN",
#         "BFA",
#         "BGD",
#         "BGR",
#         "BHR",
#         "BIH",
#         "BLR",
#         "BLZ",
#         "BMU",
#         "BOL",
#         "BRA",
#         "BRB",
#         "BRN",
#         "BTN",
#         "BWA",
#         "CAF",
#         "CAN",
#         "CHE",
#         "CHL",
#         "CHN",
#         "CIV",
#         "CMR",
#         "COD",
#         "COG",
#         "COL",
#         "CPV",
#         "CRI",
#         "CUB",
#         "CYP",
#         "CZE",
#         "DEU",
#         "DJI",
#         "DMA",
#         "DNK",
#         "DOM",
#         "DZA",
#         "ECU",
#         "EGY",
#         "ESP",
#         "EST",
#         "ETH",
#         "FIN",
#         "FRA",
#         "GAB",
#         "GBR",
# ...
